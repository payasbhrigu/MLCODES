# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
print(sklearn.__version__)
import warnings
warnings.filterwarnings('ignore')
# Out:
# 0.23.0
# 1.14.3
# 0.8.1
# 0.20.0

# %%
data = pd.read_csv('creditcard.csv',)
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data['normAmount'] = sc.fit_transform(data.Amount.values.reshape(-1,1))
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
data.drop('Amount',axis=1,inplace=True)

# %%
plt.subplots(8,4)
i = 0
d0 = data[data['Class']==0]
d1 = data[data['Class']==1]
plt.figure(figsize=(12,28))
for x in (data.columns):
    i+=1
    plt.subplot(8,4,i)
    sns.kdeplot(d0[x],label='Class 0')
    sns.kdeplot(d1[x],label='Class 1')
    plt.xlabel(x)

# %%
feats = ['V1','V2','V3','V4','V9','V10','V11','V12','V14','V16','V17','V18','V19','normAmount','Class']

# %%
def prob(x,mu,var):
    return (1/np.sqrt(2*np.pi*var))*(np.exp((-1*np.square(x-mu)/2*var)))

# %%
data.loc[:5,'V5'].apply(lambda x:prob(x,np.mean(data['V5']),np.var(data['V5'])))
# Out:
# 0    0.259181
# 1    0.288047
# 2    0.227094
# 3    0.289008
# 4    0.246810
# 5    0.244139
# Name: V5, dtype: float64

# %%
#data = data[feats]
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9     ...           V21       V22       V23       V24  \
# 0  0.098698  0.363787     ...     -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425     ...     -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654     ...      0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024     ...     -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739     ...     -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
X_neg = data[data['Class']==0]
X_neg = X_neg.loc[:,X_neg.columns!='Class']
X_pos = data[data['Class']==1]
X_pos = X_pos.loc[:,X_pos.columns!='Class']
X = data.loc[:,data.columns!='Class']
y = data['Class']
neg_index = X_neg.index.tolist()

# %%
pos_index1 = np.random.choice(X_pos.index.tolist(),246,replace=False)
pos_index1 = pos_index1.tolist()

# %%
pos_index2 = [x for x in X_pos.index.tolist() if x not in pos_index1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_neg,y.iloc[neg_index],random_state=42,test_size=0.2)
X_train,X_valid,y_train,y_valid = train_test_split(X_train,y_train,random_state=42,test_size=0.2)

# %%
from random import shuffle

# %%
test_index = X_test.index.tolist() + pos_index1
shuffle(test_index)

# %%
valid_index = X_valid.index.tolist() + pos_index2
shuffle(valid_index)

# %%
shuffle(test_index)
shuffle(valid_index)

# %%
X_test = X.loc[test_index,:]
X_valid = X.loc[valid_index,:]
y_test = y.loc[test_index]
y_valid = y.loc[valid_index]

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape,X_valid.shape,y_valid.shape
# Out:
# ((181961, 30), (57109, 30), (181961,), (57109,), (45737, 30), (45737,))

# %%
y_test.head()
# Out:
# 105469    0
# 42564     0
# 160317    0
# 279651    0
# 155581    0
# Name: Class, dtype: int64

# %%
def estimate_gaussian(X):
    mu = X.mean(axis=0)
    var = X.var(axis=0)
    return mu,var

# %%
from scipy import stats

# %%
mu,var = estimate_gaussian(X_train)
p = np.zeros((X_train.shape[0], X_train.shape[1]))
j = 0
for i in X_train.columns:
    p[:,j] = stats.norm(mu.loc[i], var.loc[i]).pdf(X_train.loc[:,i])
    j+=1

# %%
mu,var = estimate_gaussian(X_valid)
pval = np.zeros((X_valid.shape[0], X_valid.shape[1]))
j = 0
for i in X_valid.columns:
    pval[:,j] = stats.norm(mu.loc[i], var.loc[i]).pdf(X_valid.loc[:,i])
    j+=1

# %%
pval.max()
# Out:
# 3.6615204672022537

# %%
def select_threshold(pval, yval):
    best_epsilon = 0
    best_f1 = 0
    f1 = 0
    yval = yval.values
    
    for i in range(pval.shape[1]):
        step = (pval[:,i].max() - pval[:,i].min()) / 1000
        for epsilon in np.arange(pval[:,i].min(), pval[:,i].max(), step):
            
            preds = pval[:,i] < epsilon

            tp = np.sum(np.logical_and(preds == 1, yval == 1)).astype(float)
            fp = np.sum(np.logical_and(preds == 1, yval == 0)).astype(float)
            fn = np.sum(np.logical_and(preds == 0, yval == 1)).astype(float)

            precision = tp / (tp + fp)
            recall = tp / (tp + fn)
            f1 = (2 * precision * recall) / (precision + recall)

            if f1 > best_f1:
                best_f1 = f1
                best_epsilon = epsilon
    
    return best_epsilon, best_f1

epsilon, f1 = select_threshold(pval, y_valid)
epsilon, f1
# Out:
# (0.0003342770973139092, 0.7294685990338164)

# %%
np.where(p<epsilon)[0]
# Out:
# array([     0,      1,      1, ..., 181958, 181959, 181960], dtype=int64)

# %%
X_train.head()
# Out:
#             Time         V1        V2        V3        V4        V5        V6  \
# 248091  153790.0  -2.266891 -0.686125  1.656808 -1.888003 -0.850675 -0.375887
# 131867   79766.0   1.082066 -0.902599  0.087824 -0.576669 -1.048013 -0.756173
# 106248   69887.0   0.974854 -0.391819  0.666218  0.275133 -1.036884 -1.104519
# 80338    58440.0 -10.868710 -6.565963 -1.775550  0.747945  0.605049  0.026273
# 62276    50207.0   1.104077  0.044596  0.480922  1.343177 -0.335873 -0.017147
#
#               V7        V8        V9     ...           V20       V21  \
# 248091 -0.775218  0.275552  1.354245     ...     -0.293925 -0.236405
# 131867 -0.205973 -0.195959 -1.258179     ...     -0.150624 -0.244169
# 106248  0.022989 -0.231424  0.206159     ...      0.242814 -0.134384
# 80338   2.262168 -2.623900  2.271475     ...     -6.980950 -2.379129
# 62276  -0.135483  0.206887  0.257257     ...     -0.285701 -0.054159
#
#              V22       V23       V24       V25       V26       V27       V28  \
# ...

# %%
y_train.head()
# Out:
# 248091    0
# 131867    0
# 106248    0
# 80338     0
# 62276     0
# Name: Class, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
preds = rfc.predict(X_valid)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_true=y_valid.values,y_pred=preds)
# Out:
# array([[45491,     0],
#        [  246,     0]], dtype=int64)

# %%
preds.tolist().count(0)
# Out:
# 45737

# %%
sns.pairplot(data.loc[:,['V13','V15']])

# %%
from sklearn.decomposition import PCA

# %%
sc = PCA(n_components=2)

# %%
sc.fit(data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
data_pca = sc.transform(data)

# %%
plt.scatter(data_pca[:,0],data_pca[:,1])

# %%
#Using autoencoders

# %%
from keras.layers import Input, Dense
from keras.models import Model, Sequential
from keras import regularizers
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn import preprocessing 
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
np.random.seed(203)

data = pd.read_csv("creditcard.csv")
#data["Time"] = data["Time"].apply(lambda x : x / 3600 % 24)
data.drop('Time',axis=1,inplace=True)

data.head()
# Out:
# Using TensorFlow backend.
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...         V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...   -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ...   -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...    0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ...   -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...   -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
non_fraud = data[data['Class'] == 0]#.sample(1000)
fraud = data[data['Class'] == 1]

df = non_fraud.append(fraud).sample(frac=1).reset_index(drop=True)
X = df.drop(['Class'], axis = 1).values
Y = df["Class"].values

# %%
def tsne_plot(x1, y1, name="graph.png"):
    tsne = TSNE(n_components=2, random_state=0)
    X_t = tsne.fit_transform(x1)
    print(X_t)
    plt.figure(figsize=(12, 8))
    plt.scatter(X_t[np.where(y1 == 0), 0], X_t[np.where(y1 == 0), 1], marker='o', color='g', linewidth='1', alpha=0.8, label='Non Fraud')
    plt.scatter(X_t[np.where(y1 == 1), 0], X_t[np.where(y1 == 1), 1], marker='o', color='r', linewidth='1', alpha=0.8, label='Fraud')

    plt.legend(loc='best');
    plt.savefig(name);
    plt.show();
    
tsne_plot(X, Y, "original.png")

# %%
##input layer
input_layer = Input(shape=(X.shape[1],))

##encoding part
encoded = Dense(100,activation='tanh',activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoded = Dense(50,activation='relu')(encoded)

##decoding part
## decoding part
decoded = Dense(50, activation='tanh')(encoded)
decoded = Dense(100, activation='tanh')(decoded)

##output layer
output_layer = Dense(X.shape[1],activation='relu')(decoded)

# %%
##combine encoder and decoder
autoencoder = Model(input_layer,output_layer)
autoencoder.compile(optimizer='adadelta',loss='mse')

# %%
x = data.drop(["Class"], axis=1)
y = data["Class"].values

x_scale = preprocessing.MinMaxScaler().fit_transform(x.values)
x_norm, x_fraud = x_scale[y == 0], x_scale[y == 1]

# %%
autoencoder.fit(x_norm[0:2000], x_norm[0:2000], 
                batch_size = 256, epochs = 10, 
                shuffle = True, validation_split = 0.20);
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/10
# 1600/1600 [==============================] - 1s 433us/step - loss: 0.7351 - val_loss: 0.4610
# Epoch 2/10
# 1600/1600 [==============================] - 0s 23us/step - loss: 0.4245 - val_loss: 0.2815
# Epoch 3/10
# 1600/1600 [==============================] - 0s 20us/step - loss: 0.2645 - val_loss: 0.1941
# Epoch 4/10
# 1600/1600 [==============================] - 0s 20us/step - loss: 0.1927 - val_loss: 0.1486
# Epoch 5/10
# 1600/1600 [==============================] - 0s 21us/step - loss: 0.1481 - val_loss: 0.1554
# Epoch 6/10
# 1600/1600 [==============================] - 0s 19us/step - loss: 0.1664 - val_loss: 0.1175
# Epoch 7/10
# 1600/1600 [==============================] - 0s 17us/step - loss: 0.1224 - val_loss: 0.1221
# Epoch 8/10
# 1600/1600 [==============================] - 0s 19us/step - loss: 0.1383 - val_loss: 0.1051
# Epoch 9/10
# ...

# %%
hidden_representation = Sequential()
hidden_representation.add(autoencoder.layers[0])
hidden_representation.add(autoencoder.layers[1])
hidden_representation.add(autoencoder.layers[2])

# %%
norm_hid_rep = hidden_representation.predict(x_norm[:3000])
fraud_hid_rep = hidden_representation.predict(x_fraud)

# %%
rep_x = np.append(norm_hid_rep, fraud_hid_rep, axis = 0)
y_n = np.zeros(norm_hid_rep.shape[0])
y_f = np.ones(fraud_hid_rep.shape[0])
rep_y = np.append(y_n, y_f)
tsne_plot(rep_x, rep_y, "latent_representation.png")
# Out:
# [[-20.086847 -23.066732]
#  [ 27.445818   8.053432]
#  [ 25.030128 -66.40647 ]
#  ...
#  [ 60.087234 -21.864155]
#  [ 69.75194  -23.979708]
#  [ 25.326946  18.742262]]

# %%
from IPython.display import display, Image, HTML
display(HTML("""<table align="center">
<tr ><td><b>Actual Representation (Before) </b></td><td><b>Latent Representation (Actual)</b></td></tr>
<tr><td><img src='original.png'></td><td>
             <img src='latent_representation.png'></td></tr></table>"""))
# Out:
# <table align="center">
# <tr ><td><b>Actual Representation (Before) </b></td><td><b>Latent Representation (Actual)</b></td></tr>
# <tr><td><img src='original.png'></td><td>
#              <img src='latent_representation.png'></td></tr></table>

# %%
X_train,X_valid,y_train,y_valid = train_test_split(rep_x,rep_y,test_size=0.25)
clf = LogisticRegression(solver='lbfgs').fit(X_train,y_train)
pred_y = clf.predict(X_valid)

# %%
print ("")
print ("Classification Report: ")
print (classification_report(y_valid, pred_y))

print ("")
print ("Accuracy Score: ", accuracy_score(y_valid, pred_y))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98       754
#          1.0       1.00      0.71      0.83       119
#
#    micro avg       0.96      0.96      0.96       873
#    macro avg       0.98      0.85      0.90       873
# weighted avg       0.96      0.96      0.96       873
#
#
# Accuracy Score:  0.9599083619702177

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true=y_valid, y_pred=pred_y)
# Out:
# array([[754,   0],
#        [ 35,  84]], dtype=int64)

# %%
X_train.shape
# Out:
# (2619, 50)

# %%
X_valid.shape
# Out:
# (873, 50)

# %% [markdown]
# # EDUONIX:

# %%
data = pd.read_csv('creditcard.csv',)

# %%
data = data.sample(frac=0.1,random_state=1)

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027D87480F28>,
# ...
#       dtype=object)

# %%
Fraud = data[data['Class'] == 1]
Valid = data[data['Class'] == 0]

# %%
outlier_fraction = len(Fraud)/float(len(Valid))
outlier_fraction
# Out:
# 0.0017234102419808666

# %%
print("Fraud transactions: {}".format(len(Fraud)))
print("Valid transactions: {}".format(len(Valid)))
# Out:
# Fraud transactions: 49
# Valid transactions: 28432

# %%
X = data.loc[:,data.columns!="Class"]
y = data.Class
X.shape,y.shape
# Out:
# ((28481, 30), (28481,))

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

state = 1

classifiers = {
    "Isolation Forest": IsolationForest(max_samples=len(X),
                                       contamination=outlier_fraction,
                                       random_state=state),
    "Local Outlier Fractor": LocalOutlierFactor(
    n_neighbors=20,
    contamination=outlier_fraction)
}

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=state)

# %%
plt.figure(figsize=(9,7))
n_outliers = len(Fraud)

for i,(clf_name,clf) in enumerate(classifiers.items()):
    # fit the data and tag outliers
    if clf_name == "Local Outlier Factor":
        y_pred = clf.fit_predict(X_train)
        scores_pred = clf.negative_outlier_factor_
    else:
        clf.fit(X_train)
        scores_pred = clf.decision_function(X_train)
        y_pred = clf.predict(X_test)
    
    # Reshape the prediction values to 0 for valid, 1 for fraud. 
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    
    n_errors = (y_pred != y_test).sum()
    
    # Run classification metrics
    print('{}: {}'.format(clf_name, n_errors))
    #print(accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\ensemble\iforest.py:224: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Anaconda\lib\site-packages\sklearn\ensemble\iforest.py:251: UserWarning: max_samples (28481) is greater than the total number of samples (21360). max_samples will be set to n_samples for estimation.
#   % (self.max_samples, n_samples))
# C:\Anaconda\lib\site-packages\sklearn\ensemble\iforest.py:418: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# Isolation Forest: 19
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7112
#            1       0.08      0.11      0.10         9
#
#    micro avg       1.00      1.00      1.00      7121
# ...
